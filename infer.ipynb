# %%
# !export PYTHONPATH="/home/cyl/Reconst/KAF-Net"

# %%
import argparse
import json
from multiprocessing import process
import torch
import numpy as np
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt
import cv2
import os

from nets.kaf import resdcn

# %%
a = torch.rand(14,2,8)

# %%
a
# Out:
# tensor([[[0.3716, 0.4230, 0.1783, 0.7451, 0.1488, 0.5654, 0.9629, 0.6146],
#          [0.8920, 0.4644, 0.9246, 0.8589, 0.8225, 0.3216, 0.1325, 0.7216]],
#
#         [[0.4794, 0.1488, 0.4923, 0.0526, 0.8229, 0.9436, 0.5196, 0.9528],
#          [0.1211, 0.5003, 0.1771, 0.3341, 0.0652, 0.7942, 0.3585, 0.6007]],
#
#         [[0.2308, 0.4001, 0.9031, 0.9374, 0.3734, 0.0574, 0.8215, 0.4234],
#          [0.9599, 0.3824, 0.6154, 0.9798, 0.7577, 0.9077, 0.3404, 0.4631]],
#
#         [[0.5490, 0.3803, 0.6079, 0.7474, 0.7399, 0.6809, 0.8708, 0.9948],
#          [0.1894, 0.3181, 0.1199, 0.2854, 0.8057, 0.9298, 0.8484, 0.6984]],
#
#         [[0.1084, 0.7289, 0.2600, 0.6237, 0.7235, 0.5388, 0.8399, 0.3653],
#          [0.3719, 0.4879, 0.6155, 0.5451, 0.2361, 0.5249, 0.6029, 0.6973]],
#
#         [[0.8422, 0.8541, 0.4652, 0.2871, 0.8504, 0.0345, 0.7978, 0.7530],
#          [0.0803, 0.3812, 0.2782, 0.5562, 0.6917, 0.3211, 0.9798, 0.3517]],
#
# ...

# %%
a.reshape(28,8)
# Out:
# tensor([[0.3716, 0.4230, 0.1783, 0.7451, 0.1488, 0.5654, 0.9629, 0.6146],
#         [0.8920, 0.4644, 0.9246, 0.8589, 0.8225, 0.3216, 0.1325, 0.7216],
#         [0.4794, 0.1488, 0.4923, 0.0526, 0.8229, 0.9436, 0.5196, 0.9528],
#         [0.1211, 0.5003, 0.1771, 0.3341, 0.0652, 0.7942, 0.3585, 0.6007],
#         [0.2308, 0.4001, 0.9031, 0.9374, 0.3734, 0.0574, 0.8215, 0.4234],
#         [0.9599, 0.3824, 0.6154, 0.9798, 0.7577, 0.9077, 0.3404, 0.4631],
#         [0.5490, 0.3803, 0.6079, 0.7474, 0.7399, 0.6809, 0.8708, 0.9948],
#         [0.1894, 0.3181, 0.1199, 0.2854, 0.8057, 0.9298, 0.8484, 0.6984],
#         [0.1084, 0.7289, 0.2600, 0.6237, 0.7235, 0.5388, 0.8399, 0.3653],
#         [0.3719, 0.4879, 0.6155, 0.5451, 0.2361, 0.5249, 0.6029, 0.6973],
#         [0.8422, 0.8541, 0.4652, 0.2871, 0.8504, 0.0345, 0.7978, 0.7530],
#         [0.0803, 0.3812, 0.2782, 0.5562, 0.6917, 0.3211, 0.9798, 0.3517],
#         [0.2327, 0.4608, 0.2529, 0.6041, 0.1668, 0.3235, 0.5462, 0.8425],
# ...
